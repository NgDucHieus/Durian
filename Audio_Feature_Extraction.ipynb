# %%
import numpy as np 
import librosa 
from sklearn.metrics import pairwise 
 
def extract_features(file_path): 
    # Load the audio file 
    y, sr = librosa.load(file_path, sr=None) 
     
    # Extract MFCCs 
    mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13) 
     
    # Take the mean of the MFCCs across time 
    mfccs_mean = np.mean(mfccs.T, axis=0) 
     
    return mfccs_mean 

Unripe_mean  = extract_features('Unripe.wav')
Ripe_mean = extract_features('Ripe.wav')

# %%
from scipy.io import wavfile
import numpy as np

# Đọc tệp âm thanh
samplerate, data = wavfile.read('Unripe.wav')

# Ví dụ: tính toán phổ Fourier
from scipy.fft import fft

# Chuyển đổi dữ liệu âm thanh thành phổ Fourier
N = len(data)
T = 1.0 / samplerate
x = np.linspace(0.0, N*T, N, endpoint=False)
yf = fft(data)
xf = np.fft.fftfreq(N, T)[:N//2]

# Hiển thị phổ Fourier
plt.plot(xf, 2.0/N * np.abs(yf[:N//2]))
plt.grid()
plt.title('Fourier Transform')
plt.show()

# %%
Unripe_mean
# Out:
# array([-395.943   ,   59.143013,  -14.537815,   57.666935,  -25.140682,
#           7.905538,   -6.460864,   16.997942,  -15.491007,   19.132956,
#          -8.102159,    8.547199,    2.119703], dtype=float32)

# %%
Ripe_mean
# Out:
# array([-321.014    ,  119.07445  ,   -9.38666  ,   68.40242  ,
#          -4.135049 ,   33.36861  ,    4.0587955,   26.312757 ,
#          -9.825016 ,   26.56755  ,   -4.653347 ,   10.495464 ,
#           6.3485036], dtype=float32)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Your data
data = np.array([-395.943   ,   59.143013,  -14.537815,   57.666935,  -25.140682,
          7.905538,   -6.460864,   16.997942,  -15.491007,   19.132956,
         -8.102159,    8.547199,    2.119703], dtype=np.float32)

# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(range(len(data)), data, color='skyblue')
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Bar Plot of Array Values')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Your data
data = np.array([-321.014, 119.07445, -9.38666, 68.40242, -4.135049, 33.36861, 4.0587955, 26.312757, 
                  -9.825016, 26.56755, -4.653347, 10.495464, 6.3485036], dtype=np.float32)

# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(range(len(data)), data, color='skyblue')
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Bar Plot of Array Values')
plt.show()

# %%
file_path = '31.m4a'
y, sr = librosa.load(file_path, sr=None)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3556\4262660775.py:2: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(file_path, sr=None)
# C:\Users\Admin\anaconda3\lib\site-packages\librosa\core\audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)

# %%
# Out:
# 48000
